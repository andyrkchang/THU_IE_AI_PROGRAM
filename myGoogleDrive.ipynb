# %% [markdown]
# # get my google Drive file

# %%
# Read file from Google Drive

from google.colab import drive
import os
drive.mount('/content/gdrive')

# %%
# display the current working director

# !pwd

# %%
# list /content director file list

# !ls -al

# %%
# change the director path

# %cd gdrive

# %%
# display the current working director

# !pwd

# %%
# list /content director file list

# !ls -al

# %%
# change the director path

# %cd 'My Drive'
# !pwd
# !ls -al

# %%
# change the director path

# %cd 'Colab Notebooks'
# !pwd
# !ls -al

# %%
# change the director path

# %cd '/content/gdrive/My Drive/Colab Notebooks/ReinforcementLearning/movies'
# !pwd
# !ls -al
