# %% [markdown]
# # Loading Datasts
# 我們目前引入sklearn的boston房價資料庫

# %% [markdown]
# # 觀察資料型態

# %%
from  sklearn.datasets import load_boston
boston = load_boston()
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# # 資料集簡介

# %%
print(boston.DESCR)
print(boston.feature_names)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# # Feature

# %%
print(boston.data)
print(boston.data.shape)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]
# (506, 13)

# %%
print(boston.data[0])
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00]

# %% [markdown]
#       CRIM - 按城鎮劃分的人均犯罪率
#       ZN -  佔住宅用地的比例超過25,000平方英尺。
#       INDUS - 每個城鎮非零售業務佔比的比例
#       CHAS - Charles River虛擬變量（如果管道限制河流則= 1;否則為0）
#       NOX - 一氧化氮濃度（每千萬份）
#       RM - 每間住宅的平均房間數
#       AGE -  1940年以前建造的自有住房單位的年齡比例
#       DIS　-  加權距離到波士頓的五個就業中心
#       RAD - 徑向高速公路可達性的指數
#       TAX  - 每10,000美元的TAX全價物業稅率
#       PTRATIO - 按城鎮分配學生與教師的比例
#       B -  1000（Bk-0.63^2其中Bk是城鎮黑人的比例
#       LSTAT -  ％人口較低的地位
#       MEDV -  MEDV中位數自住房價值1000美元

# %% [markdown]
# # Label

# %%
print(boston.target)
print(boston.target.shape)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %% [markdown]
# # 整理資料

# %%
import pandas as pd

df = pd.DataFrame(boston.data,columns = boston.feature_names)
df['PRICE'] = boston.target 
df.head(10) # 列出前10筆
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# 5  0.02985   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21   28.7
# 6  0.08829  12.5   7.87   0.0  0.524  ...  311.0     15.2  395.60  12.43   22.9
# 7  0.14455  12.5   7.87   0.0  0.524  ...  311.0     15.2  396.90  19.15   27.1
# 8  0.21124  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.63  29.93   16.5
# 9  0.17004  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.71  17.10   18.9
#
# [10 rows x 14 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ### 變數間的相關分析

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), square=True, annot=True, cmap="RdBu_r") #center=0, cmap="YlGnBu"
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### 以RM(房間數量)為例

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(boston.data,columns = boston.feature_names)
df['PRICE'] = boston.target


plt.scatter(df['RM'],df['PRICE'], alpha=0.7)
plt.ylabel('PRICE')
plt.xlabel('RM')
# Out:
# Text(0.5, 0, 'RM')

# %% [markdown]
# ### 以LSTAT(低收入人口比例)為例

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(boston.data,columns = boston.feature_names)
df['PRICE'] = boston.target


plt.scatter( df['LSTAT'],df['PRICE'], alpha=0.7)
plt.xlabel('LSTAT')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %% [markdown]
# ### 以CRIM(城市的人均犯罪率)為例

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(boston.data,columns = boston.feature_names)
df['PRICE'] = boston.target


plt.scatter( df['CRIM'], df['PRICE'],alpha=0.7)
plt.xlabel('CRIM')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %% [markdown]
# ### 以下為次數直方圖展示

# %% [markdown]
# ### 以 DIS (與5個波士頓就業中心的距離)

# %%
dis=df['DIS']
plt.hist(dis,bins=50)
# Out:
# (array([12., 27., 33., 43., 35., 31., 23., 27., 17., 13., 19., 16., 17.,
#         18., 11., 15., 12.,  3., 16., 15.,  9.,  6.,  6., 13., 12.,  7.,
#          4.,  2., 11.,  2.,  6.,  7.,  2.,  1.,  3.,  2.,  5.,  0.,  0.,
#          0.,  0.,  0.,  2.,  2.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 1.1296  ,  1.349538,  1.569476,  1.789414,  2.009352,  2.22929 ,
#          2.449228,  2.669166,  2.889104,  3.109042,  3.32898 ,  3.548918,
#          3.768856,  3.988794,  4.208732,  4.42867 ,  4.648608,  4.868546,
#          5.088484,  5.308422,  5.52836 ,  5.748298,  5.968236,  6.188174,
#          6.408112,  6.62805 ,  6.847988,  7.067926,  7.287864,  7.507802,
#          7.72774 ,  7.947678,  8.167616,  8.387554,  8.607492,  8.82743 ,
#          9.047368,  9.267306,  9.487244,  9.707182,  9.92712 , 10.147058,
#         10.366996, 10.586934, 10.806872, 11.02681 , 11.246748, 11.466686,
#         11.686624, 11.906562, 12.1265  ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# ### 以B(城鎮的黑人比例)

# %%
bk=df['B']
plt.hist(bk,bins=50)
# Out:
# (array([  7.,   2.,   4.,   4.,   1.,   1.,   2.,   1.,   2.,   0.,   2.,
#           3.,   4.,   1.,   0.,   0.,   2.,   0.,   0.,   0.,   0.,   2.,
#           1.,   0.,   0.,   0.,   1.,   0.,   1.,   1.,   2.,   1.,   2.,
#           1.,   1.,   1.,   3.,   1.,   4.,   2.,   5.,   4.,   4.,   8.,
#          12.,  10.,  16.,  41.,  53., 293.]),
#  array([3.200000e-01, 8.251600e+00, 1.618320e+01, 2.411480e+01,
#         3.204640e+01, 3.997800e+01, 4.790960e+01, 5.584120e+01,
#         6.377280e+01, 7.170440e+01, 7.963600e+01, 8.756760e+01,
#         9.549920e+01, 1.034308e+02, 1.113624e+02, 1.192940e+02,
#         1.272256e+02, 1.351572e+02, 1.430888e+02, 1.510204e+02,
#         1.589520e+02, 1.668836e+02, 1.748152e+02, 1.827468e+02,
#         1.906784e+02, 1.986100e+02, 2.065416e+02, 2.144732e+02,
#         2.224048e+02, 2.303364e+02, 2.382680e+02, 2.461996e+02,
#         2.541312e+02, 2.620628e+02, 2.699944e+02, 2.779260e+02,
# ...

# %% [markdown]
# ## Plot all Feature with Price Scatter Plot

# %%
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
import math
rcParams['figure.figsize'] = 10, 10
fig, axes = plt.subplots(4,4)
for i in range(13):
    x_f = i%4
    y_f = math.floor((i)/4)
    axes[x_f, y_f].scatter(boston_data.data[:,i], boston_data.target) 
    axes[x_f, y_f].set_xlabel(features[i])
    axes[x_f, y_f].set_ylabel('prices')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-833542e6bed5> in <module>()
#       1 features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
#       2 import math
# ----> 3 rcParams['figure.figsize'] = 10, 10
#       4 fig, axes = plt.subplots(4,4)
#       5 for i in range(13):
#
# NameError: name 'rcParams' is not defined

# %% [markdown]
# # 將資料分割成訓練集與測試集
# *   test_size表示測試集在資料庫的比重 ( 通常設定0.2~0.3 )
# *   shuffle = True代表打亂順序
# *   可以觀察training data 與 test data 的shape發生變化

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.3, random_state= 0, shuffle=True)
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

# %% [markdown]
# # 訓練流程
# 1. 選擇模型
# 2. 建立模型
# 3. 訓練模型
# 4. 模型預測

# %%
import numpy as np
from sklearn.linear_model import LinearRegression #選擇模型
model = LinearRegression() #建立模型
model.fit(X_train,y_train) #訓練模型
y_test_pred = model.predict(X_test) #模型預測

# %% [markdown]
# # 模型成效檢驗 Evaluation

# %%
print("Mean squared error, MSE: %.2f" % np.mean((y_test_pred - y_test) ** 2))

# %%
from sklearn import metrics
print('R2 score:%.2f'%metrics.r2_score(y_test, y_test_pred))

# %% [markdown]
# # 新增特徵

# %%
import numpy as np
from  sklearn.datasets import load_boston
boston = load_boston()
boston.data = np.array([np.hstack([boston.data[i],boston.data[i][1]/boston.data[i][7],
                                  boston.data[i][1]/boston.data[i][2],boston.data[i][12]/boston.data[i][5],
                                  boston.data[i][3]/boston.data[i][4],boston.data[i][6]/boston.data[i][4]])
                        for i in range(boston.data.shape[0])])

print("feature number:",len(boston.data[0]))

# %% [markdown]
# # 重新訓練模型

# %%
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(boston.data, boston.target, test_size=0.3, random_state= 0, shuffle=True)
print(X_train_new.shape, X_test_new.shape)
print(y_train_new.shape, y_test_new.shape)

# %%
model = LinearRegression()
model.fit(X_train_new,y_train_new)
y_test_pred_new = model.predict(X_test_new)
print('train evaluation :')
print("Mean squared error, MSE: %.2f" % np.mean((y_test_new - y_test_pred_new) ** 2))
print('R2 score:%.2f'%metrics.r2_score(y_test_new, y_test_pred_new))

# %% [markdown]
# # 那如果 我們再增加更多feature呢？

# %%
from  sklearn.datasets import load_boston
boston = load_boston()
boston.data = [np.hstack([boston.data[i],np.log(boston.data[i]+1),
                                   np.power(boston.data[i],2),np.power(boston.data[i],3),
                                   np.power(boston.data[i],4),np.power(boston.data[i],5),
                                   np.power(boston.data[i],6),np.power(boston.data[i],7)])
                        for i in range(boston.data.shape[0])]

print("feature number:",len(boston.data[0]))

# %%
X_train_new2, X_test_new2, y_train_new2, y_test_new2 = train_test_split(boston.data, boston.target, test_size=0.3, random_state= 0, shuffle=True)

# %%
model = LinearRegression()
model.fit(X_train_new2,y_train_new2)
y_test_pred_new2 = model.predict(X_test_new2)
print('train evaluation :')
print("Mean squared error, MSE: %.2f" % np.mean((y_test_new2 - y_test_pred_new2 ) ** 2))
print('R2 score:%.2f'%metrics.r2_score(y_test_new2, y_test_pred_new2))

# %% [markdown]
# # Dimensionality Reduction - PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 30)
X_trans = pca.fit_transform(X_train_new2)
X_test_trans = pca.transform(X_test_new2)

print(pca.explained_variance_ratio_)

# %%
X_trans.shape

# %%
model = LinearRegression()
model.fit(X_trans,y_train_new2)
y_test_pred_new2 = model.predict(X_test_trans)
print('train evaluation :')
print("Mean squared error, MSE: %.2f" % np.mean((y_test_new2 - y_test_pred_new2 ) ** 2))
print('R2 score:%.2f'%metrics.r2_score(y_test_new2, y_test_pred_new2))

# %% [markdown]
# # Lasso - Regularization

# %%
X_train_new2, X_test_new2, y_train_new2, y_test_new2 = train_test_split(boston.data, boston.target, test_size=0.3, random_state= 0, shuffle=True)

# %%
from sklearn.linear_model import Lasso,Ridge
model = Lasso(alpha = 100,tol = 1)
model.fit(X_train_new2,y_train_new2)
y_test_pred_lasso = model.predict(X_test_new2)
print('train evaluation :')
print("Mean squared error, MSE: %.2f" % np.mean((y_test_pred_lasso - y_test_new2) ** 2))
print('R2 score:%.2f'%metrics.r2_score(y_test_new2, y_test_pred_lasso))

# %% [markdown]
# # Ridge- Regularization

# %%
X_train_new2, X_test_new2, y_train_new2, y_test_new2 = train_test_split(boston.data, boston.target, test_size=0.3, random_state= 0, shuffle=True)

# %%
model = Ridge(alpha = 0.001)
model.fit(X_train_new2,y_train_new2)
y_test_pred_Ridge = model.predict(X_test_new2)
print('train evaluation :')
print("Mean squared error, MSE: %.2f" % np.mean((y_test_pred_Ridge - y_test_new2) ** 2))
print('R2 score:%.2f'%metrics.r2_score(y_test_new2, y_test_pred_Ridge))

# %% [markdown]
# # Boston House Price
#
# Linear Regression
#
# Polynomial Regression
#
# Overfitting and Underfitting
#
# Rigde Regression
#
# Lasso Regression
#
# SVM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.model_selection import cross_val_score

from sklearn.datasets import load_boston
boston_data = load_boston()
print(boston_data.keys())

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(boston_data.data, boston_data.target, test_size=0.33, 
                                                    random_state= 42, shuffle=True)

# %% [markdown]
# ## Linear Regression

# %%
# Simple Linear Regression get One Feature [RM] to predict Price

X_rm = boston_data.data[:, 5][:, np.newaxis]
#print(X_rm)

y = boston_data.target
#print(y)

lr01 = LinearRegression()
lr01.fit(X_rm, y)

y_train_pred = lr01.predict(X_rm)

print('Slope (W_1): %.2f' % lr01.coef_[0])
print('Intercept/bias (W_0): %.2f' % lr01.intercept_)
print('(*) Linear Regression Function ===> ')
print('h(x) = %.2f' % lr01.coef_[0], ' %.2f' % lr01.intercept_, '* X'  ) 


# plot simplify our codes

def lin_regplot(X, y, model):
  plt.scatter(X, y, c='blue')
  plt.plot(X, model.predict(X), color='red', linewidth=2)
  return

plt.figure(figsize=(6,3))

lin_regplot(X_rm, y, lr01)
plt.xlabel('Average number of room [RM]')
plt.ylabel('[PRICE]')
plt.tight_layout()
plt.show()

# %%
# all data to do standardization

sc = StandardScaler()
sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

lr02 = LinearRegression()
lr02.fit(X_train_std, y_train)

y_train_pred = lr02.predict(X_train_std)
y_test_pred = lr02.predict(X_test_std)

print('(MSE) train: %.2f, test: %.2f'%(mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
print('(R^2) train: %.2f, test: %.2f'%(r2_score(y_train, y_train_pred), r2_score(y_test, y_test_pred)))

plt.figure(figsize=(6,3))

plt.scatter(
    y_train_pred, 
    y_train_pred - y_train, 
    c='blue', 
    marker='o', 
    label='Training data')

plt.scatter(
    y_test_pred, 
    y_test_pred - y_test, 
    c='lightgreen', 
    marker='s', 
    label='Test data')

plt.xlabel('Prediction values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
plt.xlim([-10, 50])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Polynomial Regression

# %%
lin_regr = LinearRegression()
quad_regr = LinearRegression()
cubic_regr = LinearRegression()

quadratic = PolynomialFeatures(degree = 2)
cubic = PolynomialFeatures(degree = 3)

X_quad_train = quadratic.fit_transform(X_train_std)
X_quad_test = quadratic.fit_transform(X_test_std)

X_cubic_train = cubic.fit_transform(X_train_std)
X_cubic_test = cubic.fit_transform(X_test_std)

lin_regr.fit(X_train_std, y_train)
linear_r2_train = r2_score(y_train, lin_regr.predict(X_train_std))
linear_r2_test = r2_score(y_test, lin_regr.predict(X_test_std))

quad_regr.fit(X_quad_train, y_train)
quad_r2_train = r2_score(y_train, quad_regr.predict(X_quad_train))
quad_r2_test = r2_score(y_test, quad_regr.predict(X_quad_test))

cubic_regr.fit(X_cubic_train, y_train)
cubic_r2_train = r2_score(y_train, cubic_regr.predict(X_cubic_train))
cubic_r2_test = r2_score(y_test, cubic_regr.predict(X_cubic_test))

print('(R^2) train:\ndegree=1: %.2f, degree=2: %.2f, degree=3: %.2f'%
     (linear_r2_train, quad_r2_train, cubic_r2_train))
print('(R^2) test:\ndegree=1: %.2f, degree=2: %.2f, degree=3: %.2f'%
     (linear_r2_test, quad_r2_test, cubic_r2_test))

# %% [markdown]
# ##Ridge Regression

# %%
ridgeReg = Ridge(alpha = 0.05, normalize=True)
ridgeReg.fit(X_cubic_train,y_train)

y_train_pred_Ridge = ridgeReg.predict(X_cubic_train)
y_test_pred_Ridge = ridgeReg.predict(X_cubic_test)

print('(MSE) train: %.2f, test: %.2f'%
      (mean_squared_error(y_train, y_train_pred_Ridge), mean_squared_error(y_test, y_test_pred_Ridge)))
print('(R^2) train: %.2f, test: %.2f'%
      (r2_score(y_train, y_train_pred_Ridge), r2_score(y_test, y_test_pred_Ridge)))

# %%
from sklearn.model_selection import cross_val_score

# Create an array of alpha and lists to store scores
alpha_space = np.logspace(-4, 0, 50)
ridge_scores = []
ridge_scores_std = []

# Create a ridge regression : ridge
ridge = Ridge(normalize=True)

# Compute scores over range of alpha
for alpha in alpha_space:
  
  ridge.alpha = alpha
  
  ridge_cv_scores = cross_val_score(ridge, X_train_std, y_train, cv=10)
  
  ridge_scores.append(np.mean(ridge_cv_scores))
  
  ridge_scores_std.append(np.std(ridge_cv_scores))
  
  def display_plot(cv_scores, cv_scores_std):
    fig = plt.figure(figsize=(6,3))
    ax = fig.add_subplot(1,1,1)
    ax.plot(alpha_space, cv_scores)
    std_error = cv_scores_std / np.sqrt(10)
    ax.fill_between(alpha_space, cv_scores + std_error, cv_scores - std_error, color='c', alpha=0.2)
    ax.set_ylabel('CV R^2 Score +/- std Error')
    ax.set_xlabel('alpha')
    ax.axhline(np.max(cv_scores), linestyle='--', color='.5')
    ax.set_xlim([alpha_space[0], alpha_space[-1]])
    ax.set_xscale('log')
    plt.show()
    
display_plot(ridge_scores, ridge_scores_std)

# %% [markdown]
# ##Lasso Regression'

# %%
lassoReg = Lasso(alpha=0.05, normalize=True)
lassoReg.fit(X_cubic_train, y_train)

y_train_pred_lasso = lassoReg.predict(X_cubic_train)
y_test_pred_lasso = lassoReg.predict(X_cubic_test)

print('(MSE) train: %.2f, test: %.2f'%
      (mean_squared_error(y_train, y_train_pred_lasso), mean_squared_error(y_test, y_test_pred_lasso)))
print('(R^2) train: %.2f, test: %.2f'%
      (r2_score(y_train, y_train_pred_lasso), r2_score(y_test, y_test_pred_lasso)))

# %%
from sklearn.model_selection import cross_val_score

# Create an array of alpha and lists to store scores
alpha_space = np.logspace(-4, 0, 50)
lasso_scores = []
lasso_scores_std = []

# Create a lasso regression : lasso
lasso = Lasso(normalize=True)

# Compute scores over range of alpha
for alpha in alpha_space:
  
  lasso.alpha = alpha
  
  lasso_cv_scores = cross_val_score(lasso, X_train_std, y_train, cv=10)
  
  lasso_scores.append(np.mean(lasso_cv_scores))
  
  lasso_scores_std.append(np.std(lasso_cv_scores))
  
  def display_plot(cv_scores, cv_scores_std):
    fig = plt.figure(figsize=(6,3))
    ax = fig.add_subplot(1,1,1)
    ax.plot(alpha_space, cv_scores)
    std_error = cv_scores_std / np.sqrt(10)
    ax.fill_between(alpha_space, cv_scores + std_error, cv_scores - std_error, color='c', alpha=0.2)
    ax.set_ylabel('CV R^2 Score +/- std Error')
    ax.set_xlabel('alpha')
    ax.axhline(np.max(cv_scores), linestyle='--', color='.5')
    ax.set_xlim([alpha_space[0], alpha_space[-1]])
    ax.set_xscale('log')
    plt.show()
    
display_plot(lasso_scores, lasso_scores_std)

# %% [markdown]
# ##SVR - super vector regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
from sklearn.datasets import load_boston
boston_data = load_boston()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(boston_data.data, boston_data.target, test_size=0.33, 
                                                    random_state= 42, shuffle=True) 

from sklearn import svm
model = svm.SVR(kernel='poly',gamma=1e-2,degree=2 , C=0.1)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn import metrics

# visualize the result
print("RMS:", np.sqrt(np.mean((y_pred - y_test) ** 2)))
print('R2:%.2f'%metrics.r2_score(y_pred, y_test))

plt.figure(figsize=(6,3))
plt.scatter(y_test, y_pred)
plt.plot([0, 50], [0, 50],'--k')
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.show()
