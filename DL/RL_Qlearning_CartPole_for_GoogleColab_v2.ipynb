# %% [markdown]
# # 3.4 利用Q學習控制CartPole
#
# <img src='https://pic1.xuehuaimg.com/proxy/csdn/https://img-blog.csdn.net/20170822173609707?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvY3Vpd2FkZXI=/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70/gravity/SouthEast'>

# %% [markdown]
# # **Run gym on the Google Colab**
#
# rvised by andy, 2020-05-17

# %%
# Andy 

#installing dependencies
# !apt-get install x11-utils

#installing dependencies
# !apt-get -qq -y install libcusparse8.0 libnvrtc8.0 libnvtoolsext1 > /dev/null
# !ln -snf /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so.8.0 /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so
# !apt-get -qq -y install xvfb freeglut3-dev ffmpeg> /dev/null
# !pip -q install gym
# !pip -q install pyglet
# !pip -q install pyopengl
# !pip -q install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils
# 0 upgraded, 2 newly installed, 0 to remove and 31 not upgraded.
# Need to get 209 kB of archives.
# After this operation, 711 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 209 kB in 1s (233 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 144433 files and directories currently installed.)
# Preparing to unpack .../libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# E: Unable to locate package libcusparse8.0
# E: Couldn't find any package by glob 'libcusparse8.0'
# E: Couldn't find any package by regex 'libcusparse8.0'
# E: Unable to locate package libnvrtc8.0
# E: Couldn't find any package by glob 'libnvrtc8.0'
# E: Couldn't find any package by regex 'libnvrtc8.0'

# %% [markdown]
# ## test

# %%
import gym
import numpy as np
env = gym.make('CartPole-v0')
print('observation space:', env.observation_space)
print('action space:', env.action_space)

obs = env.reset()
#env.render()
print('initial observation:', obs)

action = env.action_space.sample()
obs, r, done, info = env.step(action)
print('next observation:', obs)
print('reward:', r)
print('done:', done)
print('info:', info)
# Out:
# observation space: Box(4,)
# action space: Discrete(2)
# initial observation: [ 0.03651592  0.00395733  0.03261388 -0.00811701]
# next observation: [ 0.03659507 -0.1916168   0.03245154  0.29467496]
# reward: 1.0
# done: False
# info: {}

# %%
# Start virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

# %%
frames = []
for i in range(3):
    obs = env.reset()
    done = False
    R = 0
    t = 0
    while not done and t < 200:
        frames.append(env.render(mode = 'rgb_array'))
        obs, r, done, _ = env.step(env.action_space.sample())
        R += r
        t += 1
        print('next observation:', obs)
        print('reward:', r)
        print('done:', done)
        print('t:', t)
    print('test episode:', i, 'R:', R)
 
env.render()

import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np
from IPython.display import HTML

plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# next observation: [ 0.0333099  -0.21482006  0.00597992  0.30884684]
# reward: 1.0
# done: False
# t: 1
# next observation: [ 0.0290135  -0.4100267   0.01215685  0.60340966]
# reward: 1.0
# done: False
# t: 2
# next observation: [ 0.02081296 -0.21507687  0.02422505  0.31458055]
# reward: 1.0
# done: False
# t: 3
# next observation: [ 0.01651142 -0.02030823  0.03051666  0.02963477]
# reward: 1.0
# done: False
# t: 4
# next observation: [ 0.01610526  0.17436311  0.03110935 -0.25326577]
# reward: 1.0
# done: False
# t: 5
# next observation: [ 0.01959252 -0.02118892  0.02604404  0.04906502]
# reward: 1.0
# done: False
# t: 6
# next observation: [ 0.01916874 -0.21667445  0.02702534  0.34984995]
# reward: 1.0
# done: False
# t: 7
# next observation: [ 0.01483525 -0.41217012  0.03402234  0.65093087]
# reward: 1.0
# done: False
# t: 8
# next observation: [ 0.00659185 -0.60774901  0.04704095  0.95413006]
# reward: 1.0
# done: False
# t: 9
# next observation: [-0.00556313 -0.80347117  0.06612356  1.26121347]
# reward: 1.0
# done: False
# t: 10
# next observation: [-0.02163255 -0.60925427  0.09134782  0.98995094]
# reward: 1.0
# done: False
# t: 11
# next observation: [-0.03381764 -0.80547232  0.11114684  1.30986979]
# reward: 1.0
# done: False
# t: 12
# next observation: [-0.04992708 -1.00181277  0.13734424  1.63517314]
# reward: 1.0
# done: False
# t: 13
# next observation: [-0.06996334 -0.8085438   0.1700477   1.38825205]
# reward: 1.0
# done: False
# t: 14
# next observation: [-0.08613421 -0.61589933  0.19781274  1.15320664]
# reward: 1.0
# done: False
# t: 15
# next observation: [-0.0984522  -0.42382869  0.22087688  0.9284975 ]
# reward: 1.0
# done: True
# t: 16
# test episode: 0 R: 16.0
# next observation: [-0.03857918  0.15321453  0.04257421 -0.29747669]
# reward: 1.0
# done: False
# t: 1
# next observation: [-0.03551489  0.34770454  0.03662468 -0.57643431]
# reward: 1.0
# done: False
# t: 2
# next observation: [-0.0285608   0.15208887  0.02509599 -0.27244232]
# reward: 1.0
# done: False
# t: 3
# next observation: [-0.02551902 -0.04338202  0.01964714  0.02804913]
# reward: 1.0
# done: False
# t: 4
# next observation: [-0.02638666 -0.23878014  0.02020813  0.32686562]
# reward: 1.0
# done: False
# t: 5
# next observation: [-0.03116227 -0.04395164  0.02674544  0.04062333]
# reward: 1.0
# done: False
# t: 6
# next observation: [-0.0320413  -0.2394467   0.0275579   0.34162327]
# reward: 1.0
# done: False
# t: 7
# next observation: [-0.03683023 -0.43494968  0.03439037  0.64286738]
# reward: 1.0
# done: False
# t: 8
# next observation: [-0.04552923 -0.24032352  0.04724772  0.36120954]
# reward: 1.0
# done: False
# t: 9
# next observation: [-0.0503357  -0.04590388  0.05447191  0.08379119]
# reward: 1.0
# done: False
# t: 10
# next observation: [-0.05125377  0.14839664  0.05614773 -0.19122047]
# reward: 1.0
# done: False
# t: 11
# next observation: [-0.04828584 -0.04748172  0.05232332  0.11863281]
# reward: 1.0
# done: False
# t: 12
# next observation: [-0.04923548 -0.24331279  0.05469598  0.42735344]
# reward: 1.0
# done: False
# t: 13
# next observation: [-0.05410173 -0.43916502  0.06324305  0.73676507]
# reward: 1.0
# done: False
# t: 14
# next observation: [-0.06288503 -0.24497094  0.07797835  0.46463735]
# reward: 1.0
# done: False
# t: 15
# next observation: [-0.06778445 -0.05103249  0.0872711   0.19751608]
# reward: 1.0
# done: False
# t: 16
# next observation: [-0.0688051   0.14273981  0.09122142 -0.06641107]
# reward: 1.0
# done: False
# t: 17
# next observation: [-0.0659503   0.33644354  0.0898932  -0.32897667]
# reward: 1.0
# done: False
# t: 18
# next observation: [-0.05922143  0.14016454  0.08331366 -0.00935392]
# reward: 1.0
# done: False
# t: 19
# next observation: [-0.05641814 -0.0560473   0.08312658  0.30840886]
# reward: 1.0
# done: False
# t: 20
# next observation: [-0.05753909  0.1377979   0.08929476  0.04305617]
# reward: 1.0
# done: False
# t: 21
# next observation: [-0.05478313  0.33153346  0.09015589 -0.22017158]
# reward: 1.0
# done: False
# t: 22
# next observation: [-0.04815246  0.13524622  0.08575245  0.09953345]
# reward: 1.0
# done: False
# t: 23
# next observation: [-0.04544754 -0.06099337  0.08774312  0.41799155]
# reward: 1.0
# done: False
# t: 24
# next observation: [-0.0466674   0.13278272  0.09610295  0.15420897]
# reward: 1.0
# done: False
# t: 25
# next observation: [-0.04401175  0.32640667  0.09918713 -0.10667598]
# reward: 1.0
# done: False
# t: 26
# next observation: [-0.03748362  0.13001355  0.09705361  0.21557901]
# reward: 1.0
# done: False
# t: 27
# next observation: [-0.03488335  0.32362371  0.10136519 -0.04498054]
# reward: 1.0
# done: False
# t: 28
# next observation: [-0.02841087  0.12720534  0.10046558  0.27788504]
# reward: 1.0
# done: False
# t: 29
# next observation: [-0.02586676  0.32076123  0.10602328  0.01850241]
# reward: 1.0
# done: False
# t: 30
# next observation: [-0.01945154  0.12429114  0.10639333  0.34266518]
# reward: 1.0
# done: False
# t: 31
# next observation: [-0.01696572  0.31775128  0.11324664  0.0853365 ]
# reward: 1.0
# done: False
# t: 32
# next observation: [-0.01061069  0.51108312  0.11495337 -0.16958027]
# reward: 1.0
# done: False
# t: 33
# next observation: [-3.89029384e-04  7.04388086e-01  1.11561760e-01 -4.23902137e-01]
# reward: 1.0
# done: False
# t: 34
# next observation: [ 0.01369873  0.89776746  0.10308372 -0.6794368 ]
# reward: 1.0
# done: False
# t: 35
# next observation: [ 0.03165408  1.09131788  0.08949498 -0.93796829]
# reward: 1.0
# done: False
# t: 36
# next observation: [ 0.05348044  0.89511067  0.07073562 -0.6185589 ]
# reward: 1.0
# done: False
# t: 37
# next observation: [ 0.07138265  1.089177    0.05836444 -0.8881515 ]
# reward: 1.0
# done: False
# t: 38
# next observation: [ 0.09316619  0.89331357  0.04060141 -0.57770721]
# reward: 1.0
# done: False
# t: 39
# next observation: [ 0.11103246  0.69764678  0.02904726 -0.27251537]
# reward: 1.0
# done: False
# t: 40
# next observation: [0.1249854  0.50212266 0.02359696 0.02918579]
# reward: 1.0
# done: False
# t: 41
# next observation: [0.13502785 0.3066704  0.02418067 0.32921943]
# reward: 1.0
# done: False
# t: 42
# next observation: [0.14116126 0.50143992 0.03076506 0.04425897]
# reward: 1.0
# done: False
# t: 43
# next observation: [0.15119006 0.30589063 0.03165024 0.3464876 ]
# reward: 1.0
# done: False
# t: 44
# next observation: [0.15730787 0.11033311 0.03857999 0.6489806 ]
# reward: 1.0
# done: False
# t: 45
# next observation: [0.15951453 0.30489698 0.0515596  0.36869165]
# reward: 1.0
# done: False
# t: 46
# next observation: [0.16561247 0.10908179 0.05893344 0.67717592]
# reward: 1.0
# done: False
# t: 47
# next observation: [0.16779411 0.30333755 0.07247695 0.40361455]
# reward: 1.0
# done: False
# t: 48
# next observation: [0.17386086 0.49736078 0.08054925 0.13463334]
# reward: 1.0
# done: False
# t: 49
# next observation: [0.18380808 0.30118298 0.08324191 0.45160181]
# reward: 1.0
# done: False
# t: 50
# next observation: [0.18983174 0.10498851 0.09227395 0.76931936]
# reward: 1.0
# done: False
# t: 51
# next observation: [ 0.19193151 -0.09127415  0.10766034  1.089551  ]
# reward: 1.0
# done: False
# t: 52
# next observation: [0.19010602 0.10227662 0.12945136 0.83249678]
# reward: 1.0
# done: False
# t: 53
# next observation: [0.19215156 0.29541451 0.14610129 0.58316646]
# reward: 1.0
# done: False
# t: 54
# next observation: [0.19805985 0.48822014 0.15776462 0.33984032]
# reward: 1.0
# done: False
# t: 55
# next observation: [0.20782425 0.68078678 0.16456143 0.10076824]
# reward: 1.0
# done: False
# t: 56
# next observation: [ 0.22143998  0.87321481  0.16657679 -0.13581135]
# reward: 1.0
# done: False
# t: 57
# next observation: [0.23890428 0.67614726 0.16386056 0.2044457 ]
# reward: 1.0
# done: False
# t: 58
# next observation: [ 0.25242723  0.86859299  0.16794948 -0.03239642]
# reward: 1.0
# done: False
# t: 59
# next observation: [0.26979908 0.67151056 0.16730155 0.30821302]
# reward: 1.0
# done: False
# t: 60
# next observation: [0.2832293  0.86390275 0.17346581 0.07261161]
# reward: 1.0
# done: False
# t: 61
# next observation: [0.30050735 0.66677323 0.17491804 0.41461183]
# reward: 1.0
# done: False
# t: 62
# next observation: [0.31384282 0.46965955 0.18321028 0.75693472]
# reward: 1.0
# done: False
# t: 63
# next observation: [0.32323601 0.66184747 0.19834897 0.52704055]
# reward: 1.0
# done: False
# t: 64
# next observation: [0.33647296 0.85370713 0.20888979 0.30282666]
# reward: 1.0
# done: False
# t: 65
# next observation: [0.3535471  1.04533526 0.21494632 0.0826009 ]
# reward: 1.0
# done: True
# t: 66
# test episode: 1 R: 66.0
# next observation: [ 0.00598067  0.23315967  0.00643365 -0.2892292 ]
# reward: 1.0
# done: False
# t: 1
# next observation: [ 0.01064386  0.42818929  0.00064906 -0.5798761 ]
# reward: 1.0
# done: False
# t: 2
# next observation: [ 0.01920765  0.23305825 -0.01094846 -0.28698878]
# reward: 1.0
# done: False
# t: 3
# next observation: [ 0.02386881  0.03809413 -0.01668823  0.00222109]
# reward: 1.0
# done: False
# t: 4
# next observation: [ 0.02463069 -0.15678456 -0.01664381  0.28959231]
# reward: 1.0
# done: False
# t: 5
# next observation: [ 0.021495   -0.35166527 -0.01085197  0.57697983]
# reward: 1.0
# done: False
# t: 6
# next observation: [ 0.0144617  -0.15639291  0.00068763  0.28089811]
# reward: 1.0
# done: False
# t: 7
# next observation: [ 0.01133384 -0.35152466  0.00630559  0.57379784]
# reward: 1.0
# done: False
# t: 8
# next observation: [ 0.00430335 -0.54673445  0.01778155  0.86846053]
# reward: 1.0
# done: False
# t: 9
# next observation: [-0.00663134 -0.35185888  0.03515076  0.58142089]
# reward: 1.0
# done: False
# t: 10
# next observation: [-0.01366852 -0.54745526  0.04677918  0.88496642]
# reward: 1.0
# done: False
# t: 11
# next observation: [-0.02461763 -0.3529986   0.06447851  0.60734858]
# reward: 1.0
# done: False
# t: 12
# next observation: [-0.0316776  -0.54895999  0.07662548  0.91962339]
# reward: 1.0
# done: False
# t: 13
# next observation: [-0.0426568  -0.35495269  0.09501795  0.65197221]
# reward: 1.0
# done: False
# t: 14
# next observation: [-0.04975585 -0.16127346  0.10805739  0.3906571 ]
# reward: 1.0
# done: False
# t: 15
# next observation: [-0.05298132  0.03216226  0.11587053  0.13390294]
# reward: 1.0
# done: False
# t: 16
# next observation: [-0.05233807 -0.16441234  0.11854859  0.4607774 ]
# reward: 1.0
# done: False
# t: 17
# next observation: [-0.05562632  0.02885202  0.12776414  0.20768725]
# reward: 1.0
# done: False
# t: 18
# next observation: [-0.05504928 -0.16784335  0.13191788  0.53778604]
# reward: 1.0
# done: False
# t: 19
# next observation: [-0.05840615 -0.36454919  0.1426736   0.86895263]
# reward: 1.0
# done: False
# t: 20
# next observation: [-0.06569713 -0.17162639  0.16005266  0.62431263]
# reward: 1.0
# done: False
# t: 21
# next observation: [-0.06912966  0.02094189  0.17253891  0.38600689]
# reward: 1.0
# done: False
# t: 22
# next observation: [-0.06871082 -0.17615565  0.18025905  0.7277386 ]
# reward: 1.0
# done: False
# t: 23
# next observation: [-0.07223393  0.01607727  0.19481382  0.49677088]
# reward: 1.0
# done: False
# t: 24
# next observation: [-0.07191239  0.20799582  0.20474924  0.27125229]
# reward: 1.0
# done: False
# t: 25
# next observation: [-0.06775247  0.39969748  0.21017428  0.04948277]
# reward: 1.0
# done: True
# t: 26
# test episode: 2 R: 26.0
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img76d18d9cf50a45cbb24564111ece114b">
#   <div class="anim-controls">
#     <input id="_anim_slider76d18d9cf50a45cbb24564111ece114b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim76d18d9cf50a45cbb24564111ece114b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim76d18d9cf50a45cbb24564111ece114b.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select76d18d9cf50a45cbb24564111ece114b" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_76d18d9cf50a45cbb24564111ece114b"
#              >
#       <label for="_anim_radio1_76d18d9cf50a45cbb24564111ece114b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_76d18d9cf50a45cbb24564111ece114b"
#              checked>
#       <label for="_anim_radio2_76d18d9cf50a45cbb24564111ece114b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_76d18d9cf50a45cbb24564111ece114b"
#              >
#       <label for="_anim_radio3_76d18d9cf50a45cbb24564111ece114b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img76d18d9cf50a45cbb24564111ece114b";
#     var slider_id = "_anim_slider76d18d9cf50a45cbb24564111ece114b";
#     var loop_select_id = "_anim_loop_select76d18d9cf50a45cbb24564111ece114b";
#     var frames = new Array(108);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAJlElEQVR4nO3dz4ucdwHH8e/sj7SxkY1VsRUPig0S\
# IyqUoodczUEQDwH/ECE3ySEQ8OLZk3j1UhIJ4kEE74JgGqV7UDay+KOtDcmyMW12dzwoW0q7hy5v\
# 9unsvF4wh2cenofPZYY37MzObD6fzwcAAJmVqQcAAJw2AgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawA

# %% [markdown]
# ## Main

# %%
# Andy
import gym
import numpy as np

# %%
# Andy
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np
from IPython.display import HTML

# re-define the function display_frames_as_gif by Andy 2020-05-17
# to be ran on the Google Colabollation

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    animate = lambda i: patch.set_data(frames[i])
    ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
    HTML(ani.to_jshtml())

# %%
# 常數的設定
ENV = 'CartPole-v0'  # 使用的課題名稱
NUM_DIZITIZED = 6  # 各狀態的離散值分割數
GAMMA = 0.99  # 時間折扣率
ETA = 0.5  # 學習係數
MAX_STEPS = 200  # 單回合的step數
NUM_EPISODES = 1000  # 最大回合數

# %%
class Agent:
    '''這是CartPole的智能體類別、代表的是立有棒子的推車'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # 為了讓代理器決定動作而建置頭腦

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q函數的更新'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''決定動作'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''智能體的腦袋類別，會於此類別執行Q學習'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # 取得CartPole的動作（向右或向左）的2

        # 建立Q table。列數為狀態轉換成分割數^（4個變數)的離散值、欄數為動作數量
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))


    def bins(self, clip_min, clip_max, num):
        '''計算觀測所得的狀態（連續值)轉換成離散值的臨界值'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''將觀測所得的observation狀態轉換成離散值'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''以Q學習更新Q table'''
        state = self.digitize_state(observation)  # 將狀態轉換成離散值
        state_next = self.digitize_state(observation_next)  # 將下一個狀態轉換成離散值
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        '''以ε-greedy法篩減動作，直到最後只採行最佳的動作'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 隨機傳回0,1的動作
        return action

# %% [markdown]
# ** Andy Revised**

# %%
# Start virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

# %%
# Environemt Executor

env = gym.make(ENV)  # 設定要執行的課題
num_states = env.observation_space.shape[0]  # 取得課題的狀態數4
num_actions = env.action_space.n  # 取得CartPole的動作（向右或向左）的2
agent = Agent(num_states, num_actions)  # 於環境建立採行動作的Agent

print('num_states', num_states) # Andy Add
print('num_actions', num_actions) # Andy Add

'''執行'''
complete_episodes = 0  # 連續執行195step以上的回合數
is_episode_final = False  # 最終回合的旗標
frames = []  # 儲存影像，供製作動畫之用的變數

for episode in range(NUM_EPISODES):  # 重覆執行，直到設定的回合數為止
    observation = env.reset()  # 初始化環境
    #print('initial observation:', observation) # Andy Add

    for step in range(MAX_STEPS):  # 1回合的迴圈

        if is_episode_final is True:  # 於最終回合將各時刻的影像存入frames
           frames.append(env.render(mode='rgb_array'))
           print('frames len =', len(frames))

        # 求出動作
        action = agent.get_action(observation, episode)

        # 執行動作a_t、算出s_{t+1}, r_{t+1}
        observation_next, _, done, _ = env.step(
                    action)  # 由於不會用到reward與info所以設定為_

        # 給予報酬
        if done:  # Step數超過200或棒子傾斜至一定角度時，done將為true
            if step < 195:
               reward = -1  # 中途棒子傾倒的話，將以報酬-1作為罰則
               complete_episodes = 0  # 連續195step之後，重設回合
            else:
               reward = 1  # 若棒子依然直立，給予報酬1
               complete_episodes += 1  # 更新連續記錄
        else:
            reward = 0  # 中途的報酬為0

        # 以step+1的狀態observation_next更新Q函數
        agent.update_Q_function(
            observation, action, reward, observation_next)

        # 觀測的更新
        observation = observation_next

        # 結束時的處理
        if done:
            print('{0} Episode: Finished after {1} time steps'.format(
                  episode, step + 1), 'done = ', done)
            break

        if is_episode_final is True:  # 於最終回合儲存與繪製動畫
            #display_frames_as_gif(frames)
            break

        if complete_episodes >= 10:  # 連續10回合成功的話
            print('連續10回合成功')
            is_episode_final = True  # 將下回合視為繪製動畫的最終回合
# Out:
# num_states 4
# num_actions 2
# 0 Episode: Finished after 12 time steps done =  True
# 1 Episode: Finished after 10 time steps done =  True
# 2 Episode: Finished after 16 time steps done =  True
# 3 Episode: Finished after 18 time steps done =  True
# 4 Episode: Finished after 8 time steps done =  True
# 5 Episode: Finished after 10 time steps done =  True
# 6 Episode: Finished after 15 time steps done =  True
# 7 Episode: Finished after 19 time steps done =  True
# 8 Episode: Finished after 9 time steps done =  True
# 9 Episode: Finished after 58 time steps done =  True
# 10 Episode: Finished after 14 time steps done =  True
# 11 Episode: Finished after 9 time steps done =  True
# 12 Episode: Finished after 9 time steps done =  True
# 13 Episode: Finished after 27 time steps done =  True
# 14 Episode: Finished after 74 time steps done =  True
# 15 Episode: Finished after 151 time steps done =  True
# 16 Episode: Finished after 16 time steps done =  True
# 17 Episode: Finished after 42 time steps done =  True
# 18 Episode: Finished after 11 time steps done =  True
# 19 Episode: Finished after 12 time steps done =  True
# 20 Episode: Finished after 17 time steps done =  True
# 21 Episode: Finished after 12 time steps done =  True
# 22 Episode: Finished after 51 time steps done =  True
# 23 Episode: Finished after 54 time steps done =  True
# 24 Episode: Finished after 11 time steps done =  True
# 25 Episode: Finished after 19 time steps done =  True
# 26 Episode: Finished after 18 time steps done =  True
# 27 Episode: Finished after 32 time steps done =  True
# 28 Episode: Finished after 52 time steps done =  True
# 29 Episode: Finished after 54 time steps done =  True
# 30 Episode: Finished after 116 time steps done =  True
# 31 Episode: Finished after 39 time steps done =  True
# 32 Episode: Finished after 121 time steps done =  True
# 33 Episode: Finished after 77 time steps done =  True
# 34 Episode: Finished after 60 time steps done =  True
# 35 Episode: Finished after 66 time steps done =  True
# 36 Episode: Finished after 81 time steps done =  True
# 37 Episode: Finished after 200 time steps done =  True
# 38 Episode: Finished after 47 time steps done =  True
# 39 Episode: Finished after 26 time steps done =  True
# 40 Episode: Finished after 26 time steps done =  True
# 41 Episode: Finished after 120 time steps done =  True
# 42 Episode: Finished after 13 time steps done =  True
# 43 Episode: Finished after 109 time steps done =  True
# 44 Episode: Finished after 146 time steps done =  True
# 45 Episode: Finished after 48 time steps done =  True
# 46 Episode: Finished after 97 time steps done =  True
# 47 Episode: Finished after 157 time steps done =  True
# 48 Episode: Finished after 161 time steps done =  True
# 49 Episode: Finished after 14 time steps done =  True
# 50 Episode: Finished after 28 time steps done =  True
# 51 Episode: Finished after 70 time steps done =  True
# 52 Episode: Finished after 14 time steps done =  True
# 53 Episode: Finished after 47 time steps done =  True
# 54 Episode: Finished after 57 time steps done =  True
# 55 Episode: Finished after 56 time steps done =  True
# 56 Episode: Finished after 133 time steps done =  True
# 57 Episode: Finished after 54 time steps done =  True
# 58 Episode: Finished after 95 time steps done =  True
# 59 Episode: Finished after 159 time steps done =  True
# 60 Episode: Finished after 74 time steps done =  True
# 61 Episode: Finished after 58 time steps done =  True
# 62 Episode: Finished after 157 time steps done =  True
# 63 Episode: Finished after 26 time steps done =  True
# 64 Episode: Finished after 19 time steps done =  True
# 65 Episode: Finished after 16 time steps done =  True
# 66 Episode: Finished after 16 time steps done =  True
# 67 Episode: Finished after 200 time steps done =  True
# 68 Episode: Finished after 34 time steps done =  True
# 69 Episode: Finished after 16 time steps done =  True
# 70 Episode: Finished after 16 time steps done =  True
# 71 Episode: Finished after 80 time steps done =  True
# 72 Episode: Finished after 38 time steps done =  True
# 73 Episode: Finished after 34 time steps done =  True
# 74 Episode: Finished after 147 time steps done =  True
# 75 Episode: Finished after 15 time steps done =  True
# 76 Episode: Finished after 28 time steps done =  True
# 77 Episode: Finished after 15 time steps done =  True
# 78 Episode: Finished after 13 time steps done =  True
# 79 Episode: Finished after 44 time steps done =  True
# 80 Episode: Finished after 16 time steps done =  True
# 81 Episode: Finished after 104 time steps done =  True
# 82 Episode: Finished after 9 time steps done =  True
# 83 Episode: Finished after 32 time steps done =  True
# 84 Episode: Finished after 34 time steps done =  True
# 85 Episode: Finished after 40 time steps done =  True
# 86 Episode: Finished after 11 time steps done =  True
# 87 Episode: Finished after 42 time steps done =  True
# 88 Episode: Finished after 57 time steps done =  True
# 89 Episode: Finished after 77 time steps done =  True
# 90 Episode: Finished after 87 time steps done =  True
# 91 Episode: Finished after 89 time steps done =  True
# 92 Episode: Finished after 111 time steps done =  True
# 93 Episode: Finished after 72 time steps done =  True
# 94 Episode: Finished after 124 time steps done =  True
# 95 Episode: Finished after 36 time steps done =  True
# 96 Episode: Finished after 45 time steps done =  True
# 97 Episode: Finished after 62 time steps done =  True
# 98 Episode: Finished after 77 time steps done =  True
# 99 Episode: Finished after 33 time steps done =  True
# 100 Episode: Finished after 106 time steps done =  True
# 101 Episode: Finished after 98 time steps done =  True
# 102 Episode: Finished after 99 time steps done =  True
# 103 Episode: Finished after 36 time steps done =  True
# 104 Episode: Finished after 13 time steps done =  True
# 105 Episode: Finished after 155 time steps done =  True
# 106 Episode: Finished after 13 time steps done =  True
# 107 Episode: Finished after 77 time steps done =  True
# 108 Episode: Finished after 101 time steps done =  True
# 109 Episode: Finished after 101 time steps done =  True
# 110 Episode: Finished after 88 time steps done =  True
# 111 Episode: Finished after 116 time steps done =  True
# 112 Episode: Finished after 128 time steps done =  True
# 113 Episode: Finished after 154 time steps done =  True
# 114 Episode: Finished after 200 time steps done =  True
# 115 Episode: Finished after 200 time steps done =  True
# 116 Episode: Finished after 150 time steps done =  True
# 117 Episode: Finished after 132 time steps done =  True
# 118 Episode: Finished after 103 time steps done =  True
# 119 Episode: Finished after 163 time steps done =  True
# 120 Episode: Finished after 200 time steps done =  True
# 121 Episode: Finished after 103 time steps done =  True
# 122 Episode: Finished after 175 time steps done =  True
# 123 Episode: Finished after 163 time steps done =  True
# 124 Episode: Finished after 9 time steps done =  True
# 125 Episode: Finished after 200 time steps done =  True
# 126 Episode: Finished after 102 time steps done =  True
# 127 Episode: Finished after 9 time steps done =  True
# 128 Episode: Finished after 138 time steps done =  True
# 129 Episode: Finished after 80 time steps done =  True
# 130 Episode: Finished after 153 time steps done =  True
# 131 Episode: Finished after 121 time steps done =  True
# 132 Episode: Finished after 107 time steps done =  True
# 133 Episode: Finished after 49 time steps done =  True
# 134 Episode: Finished after 120 time steps done =  True
# 135 Episode: Finished after 119 time steps done =  True
# 136 Episode: Finished after 114 time steps done =  True
# 137 Episode: Finished after 187 time steps done =  True
# 138 Episode: Finished after 193 time steps done =  True
# 139 Episode: Finished after 200 time steps done =  True
# 140 Episode: Finished after 16 time steps done =  True
# 141 Episode: Finished after 200 time steps done =  True
# 142 Episode: Finished after 163 time steps done =  True
# 143 Episode: Finished after 147 time steps done =  True
# 144 Episode: Finished after 199 time steps done =  True
# 145 Episode: Finished after 191 time steps done =  True
# 146 Episode: Finished after 200 time steps done =  True
# 147 Episode: Finished after 200 time steps done =  True
# 148 Episode: Finished after 200 time steps done =  True
# 149 Episode: Finished after 148 time steps done =  True
# 150 Episode: Finished after 175 time steps done =  True
# 151 Episode: Finished after 183 time steps done =  True
# 152 Episode: Finished after 179 time steps done =  True
# 153 Episode: Finished after 142 time steps done =  True
# 154 Episode: Finished after 200 time steps done =  True
# 155 Episode: Finished after 200 time steps done =  True
# 156 Episode: Finished after 146 time steps done =  True
# 157 Episode: Finished after 200 time steps done =  True
# 158 Episode: Finished after 200 time steps done =  True
# 159 Episode: Finished after 155 time steps done =  True
# 160 Episode: Finished after 195 time steps done =  True
# 161 Episode: Finished after 200 time steps done =  True
# 162 Episode: Finished after 199 time steps done =  True
# 163 Episode: Finished after 116 time steps done =  True
# 164 Episode: Finished after 154 time steps done =  True
# 165 Episode: Finished after 127 time steps done =  True
# 166 Episode: Finished after 200 time steps done =  True
# 167 Episode: Finished after 200 time steps done =  True
# 168 Episode: Finished after 200 time steps done =  True
# 169 Episode: Finished after 158 time steps done =  True
# 170 Episode: Finished after 186 time steps done =  True
# 171 Episode: Finished after 188 time steps done =  True
# 172 Episode: Finished after 200 time steps done =  True
# 173 Episode: Finished after 154 time steps done =  True
# 174 Episode: Finished after 143 time steps done =  True
# 175 Episode: Finished after 200 time steps done =  True
# 176 Episode: Finished after 146 time steps done =  True
# 177 Episode: Finished after 142 time steps done =  True
# 178 Episode: Finished after 200 time steps done =  True
# 179 Episode: Finished after 200 time steps done =  True
# 180 Episode: Finished after 133 time steps done =  True
# 181 Episode: Finished after 185 time steps done =  True
# 182 Episode: Finished after 200 time steps done =  True
# 183 Episode: Finished after 200 time steps done =  True
# 184 Episode: Finished after 200 time steps done =  True
# 185 Episode: Finished after 150 time steps done =  True
# 186 Episode: Finished after 200 time steps done =  True
# 187 Episode: Finished after 172 time steps done =  True
# 188 Episode: Finished after 180 time steps done =  True
# 189 Episode: Finished after 200 time steps done =  True
# 190 Episode: Finished after 176 time steps done =  True
# 191 Episode: Finished after 200 time steps done =  True
# 192 Episode: Finished after 200 time steps done =  True
# 193 Episode: Finished after 145 time steps done =  True
# 194 Episode: Finished after 162 time steps done =  True
# 195 Episode: Finished after 200 time steps done =  True
# 196 Episode: Finished after 200 time steps done =  True
# 197 Episode: Finished after 166 time steps done =  True
# 198 Episode: Finished after 139 time steps done =  True
# 199 Episode: Finished after 182 time steps done =  True
# 200 Episode: Finished after 155 time steps done =  True
# 201 Episode: Finished after 158 time steps done =  True
# 202 Episode: Finished after 200 time steps done =  True
# 203 Episode: Finished after 183 time steps done =  True
# 204 Episode: Finished after 175 time steps done =  True
# 205 Episode: Finished after 132 time steps done =  True
# 206 Episode: Finished after 59 time steps done =  True
# 207 Episode: Finished after 200 time steps done =  True
# 208 Episode: Finished after 200 time steps done =  True
# 209 Episode: Finished after 200 time steps done =  True
# 210 Episode: Finished after 200 time steps done =  True
# 211 Episode: Finished after 200 time steps done =  True
# 212 Episode: Finished after 200 time steps done =  True
# 213 Episode: Finished after 200 time steps done =  True
# 214 Episode: Finished after 158 time steps done =  True
# 215 Episode: Finished after 160 time steps done =  True
# 216 Episode: Finished after 200 time steps done =  True
# 217 Episode: Finished after 200 time steps done =  True
# 218 Episode: Finished after 200 time steps done =  True
# 219 Episode: Finished after 200 time steps done =  True
# 220 Episode: Finished after 200 time steps done =  True
# 221 Episode: Finished after 200 time steps done =  True
# 222 Episode: Finished after 200 time steps done =  True
# 223 Episode: Finished after 200 time steps done =  True
# 224 Episode: Finished after 200 time steps done =  True
# 225 Episode: Finished after 200 time steps done =  True
# 連續10回合成功
# frames len = 1
# frames len = 2
# frames len = 3
# frames len = 4
# frames len = 5
# frames len = 6
# frames len = 7
# frames len = 8
# frames len = 9
# frames len = 10
# frames len = 11
# frames len = 12
# frames len = 13
# frames len = 14
# frames len = 15
# frames len = 16
# frames len = 17
# frames len = 18
# frames len = 19
# frames len = 20
# frames len = 21
# frames len = 22
# frames len = 23
# frames len = 24
# frames len = 25
# frames len = 26
# frames len = 27
# frames len = 28
# frames len = 29
# frames len = 30
# frames len = 31
# frames len = 32
# frames len = 33
# frames len = 34
# frames len = 35
# frames len = 36
# frames len = 37
# frames len = 38
# frames len = 39
# frames len = 40
# frames len = 41
# frames len = 42
# frames len = 43
# frames len = 44
# frames len = 45
# frames len = 46
# frames len = 47
# frames len = 48
# frames len = 49
# frames len = 50
# frames len = 51
# frames len = 52
# frames len = 53
# frames len = 54
# frames len = 55
# frames len = 56
# frames len = 57
# frames len = 58
# frames len = 59
# frames len = 60
# frames len = 61
# frames len = 62
# frames len = 63
# frames len = 64
# frames len = 65
# frames len = 66
# frames len = 67
# frames len = 68
# frames len = 69
# frames len = 70
# frames len = 71
# frames len = 72
# frames len = 73
# frames len = 74
# frames len = 75
# frames len = 76
# frames len = 77
# frames len = 78
# frames len = 79
# frames len = 80
# frames len = 81
# frames len = 82
# frames len = 83
# frames len = 84
# frames len = 85
# frames len = 86
# frames len = 87
# frames len = 88
# frames len = 89
# frames len = 90
# frames len = 91
# frames len = 92
# frames len = 93
# frames len = 94
# frames len = 95
# frames len = 96
# frames len = 97
# frames len = 98
# frames len = 99
# frames len = 100
# frames len = 101
# frames len = 102
# frames len = 103
# frames len = 104
# frames len = 105
# frames len = 106
# frames len = 107
# frames len = 108
# frames len = 109
# frames len = 110
# frames len = 111
# frames len = 112
# frames len = 113
# frames len = 114
# frames len = 115
# frames len = 116
# frames len = 117
# frames len = 118
# frames len = 119
# frames len = 120
# frames len = 121
# frames len = 122
# frames len = 123
# frames len = 124
# frames len = 125
# frames len = 126
# frames len = 127
# frames len = 128
# frames len = 129
# frames len = 130
# frames len = 131
# frames len = 132
# frames len = 133
# frames len = 134
# frames len = 135
# frames len = 136
# frames len = 137
# frames len = 138
# frames len = 139
# frames len = 140
# frames len = 141
# frames len = 142
# frames len = 143
# frames len = 144
# frames len = 145
# frames len = 146
# frames len = 147
# frames len = 148
# frames len = 149
# frames len = 150
# frames len = 151
# frames len = 152
# frames len = 153
# frames len = 154
# frames len = 155
# frames len = 156
# frames len = 157
# frames len = 158
# frames len = 159
# frames len = 160
# frames len = 161
# frames len = 162
# frames len = 163
# frames len = 164
# frames len = 165
# frames len = 166
# frames len = 167
# frames len = 168
# frames len = 169
# frames len = 170
# frames len = 171
# frames len = 172
# frames len = 173
# frames len = 174
# frames len = 175
# frames len = 176
# frames len = 177
# frames len = 178
# frames len = 179
# frames len = 180
# frames len = 181
# frames len = 182
# frames len = 183
# frames len = 184
# frames len = 185
# frames len = 186
# frames len = 187
# frames len = 188
# frames len = 189
# frames len = 190
# frames len = 191
# frames len = 192
# frames len = 193
# frames len = 194
# frames len = 195
# frames len = 196
# frames len = 197
# frames len = 198
# frames len = 199
# frames len = 200
# frames len = 201
# frames len = 202
# frames len = 203
# frames len = 204
# frames len = 205
# frames len = 206
# frames len = 207
# frames len = 208
# frames len = 209
# frames len = 210
# frames len = 211
# frames len = 212
# frames len = 213
# frames len = 214
# frames len = 215
# frames len = 216
# frames len = 217
# frames len = 218
# frames len = 219
# frames len = 220
# frames len = 221
# frames len = 222
# frames len = 223
# frames len = 224
# frames len = 225
# frames len = 226
# frames len = 227
# frames len = 228
# frames len = 229
# frames len = 230
# frames len = 231
# frames len = 232
# frames len = 233
# frames len = 234
# frames len = 235
# frames len = 236
# frames len = 237
# frames len = 238
# frames len = 239
# frames len = 240
# frames len = 241
# frames len = 242
# frames len = 243
# frames len = 244
# frames len = 245
# frames len = 246
# frames len = 247
# frames len = 248
# frames len = 249
# frames len = 250
# frames len = 251
# frames len = 252
# frames len = 253
# frames len = 254
# frames len = 255
# frames len = 256
# frames len = 257
# frames len = 258
# frames len = 259
# frames len = 260
# frames len = 261
# frames len = 262
# frames len = 263
# frames len = 264
# frames len = 265
# frames len = 266
# frames len = 267
# frames len = 268
# frames len = 269
# frames len = 270
# frames len = 271
# frames len = 272
# frames len = 273
# frames len = 274
# frames len = 275
# frames len = 276
# frames len = 277
# frames len = 278
# frames len = 279
# frames len = 280
# frames len = 281
# frames len = 282
# frames len = 283
# frames len = 284
# frames len = 285
# frames len = 286
# frames len = 287
# frames len = 288
# frames len = 289
# frames len = 290
# frames len = 291
# frames len = 292
# frames len = 293
# frames len = 294
# frames len = 295
# frames len = 296
# frames len = 297
# frames len = 298
# frames len = 299
# frames len = 300
# frames len = 301
# frames len = 302
# frames len = 303
# frames len = 304
# frames len = 305
# frames len = 306
# frames len = 307
# frames len = 308
# frames len = 309
# frames len = 310
# frames len = 311
# frames len = 312
# frames len = 313
# frames len = 314
# frames len = 315
# frames len = 316
# frames len = 317
# frames len = 318
# frames len = 319
# frames len = 320
# frames len = 321
# frames len = 322
# frames len = 323
# frames len = 324
# frames len = 325
# frames len = 326
# frames len = 327
# frames len = 328
# frames len = 329
# frames len = 330
# frames len = 331
# frames len = 332
# frames len = 333
# frames len = 334
# frames len = 335
# frames len = 336
# frames len = 337
# frames len = 338
# frames len = 339
# frames len = 340
# frames len = 341
# frames len = 342
# frames len = 343
# frames len = 344
# frames len = 345
# frames len = 346
# frames len = 347
# frames len = 348
# frames len = 349
# frames len = 350
# frames len = 351
# frames len = 352
# frames len = 353
# frames len = 354
# frames len = 355
# frames len = 356
# frames len = 357
# frames len = 358
# frames len = 359
# frames len = 360
# frames len = 361
# frames len = 362
# frames len = 363
# frames len = 364
# frames len = 365
# frames len = 366
# frames len = 367
# frames len = 368
# frames len = 369
# frames len = 370
# frames len = 371
# frames len = 372
# frames len = 373
# frames len = 374
# frames len = 375
# frames len = 376
# frames len = 377
# frames len = 378
# frames len = 379
# frames len = 380
# frames len = 381
# frames len = 382
# frames len = 383
# frames len = 384
# frames len = 385
# frames len = 386
# frames len = 387
# frames len = 388
# frames len = 389
# frames len = 390
# frames len = 391
# frames len = 392
# frames len = 393
# frames len = 394
# frames len = 395
# frames len = 396
# frames len = 397
# frames len = 398
# frames len = 399
# frames len = 400
# frames len = 401
# frames len = 402
# frames len = 403
# frames len = 404
# frames len = 405
# frames len = 406
# frames len = 407
# frames len = 408
# frames len = 409
# frames len = 410
# frames len = 411
# frames len = 412
# frames len = 413
# frames len = 414
# frames len = 415
# frames len = 416
# frames len = 417
# frames len = 418
# frames len = 419
# frames len = 420
# frames len = 421
# frames len = 422
# frames len = 423
# frames len = 424
# frames len = 425
# frames len = 426
# frames len = 427
# frames len = 428
# frames len = 429
# frames len = 430
# frames len = 431
# frames len = 432
# frames len = 433
# frames len = 434
# frames len = 435
# frames len = 436
# frames len = 437
# frames len = 438
# frames len = 439
# frames len = 440
# frames len = 441
# frames len = 442
# frames len = 443
# frames len = 444
# frames len = 445
# frames len = 446
# frames len = 447
# frames len = 448
# frames len = 449
# frames len = 450
# frames len = 451
# frames len = 452
# frames len = 453
# frames len = 454
# frames len = 455
# frames len = 456
# frames len = 457
# frames len = 458
# frames len = 459
# frames len = 460
# frames len = 461
# frames len = 462
# frames len = 463
# frames len = 464
# frames len = 465
# frames len = 466
# frames len = 467
# frames len = 468
# frames len = 469
# frames len = 470
# frames len = 471
# frames len = 472
# frames len = 473
# frames len = 474
# frames len = 475
# frames len = 476
# frames len = 477
# frames len = 478
# frames len = 479
# frames len = 480
# frames len = 481
# frames len = 482
# frames len = 483
# frames len = 484
# frames len = 485
# frames len = 486
# frames len = 487
# frames len = 488
# frames len = 489
# frames len = 490
# frames len = 491
# frames len = 492
# frames len = 493
# frames len = 494
# frames len = 495
# frames len = 496
# frames len = 497
# frames len = 498
# frames len = 499
# frames len = 500
# frames len = 501
# frames len = 502
# frames len = 503
# frames len = 504
# frames len = 505
# frames len = 506
# frames len = 507
# frames len = 508
# frames len = 509
# frames len = 510
# frames len = 511
# frames len = 512
# frames len = 513
# frames len = 514
# frames len = 515
# frames len = 516
# frames len = 517
# frames len = 518
# frames len = 519
# frames len = 520
# frames len = 521
# frames len = 522
# frames len = 523
# frames len = 524
# frames len = 525
# frames len = 526
# frames len = 527
# frames len = 528
# frames len = 529
# frames len = 530
# frames len = 531
# frames len = 532
# frames len = 533
# frames len = 534
# frames len = 535
# frames len = 536
# frames len = 537
# frames len = 538
# frames len = 539
# frames len = 540
# frames len = 541
# frames len = 542
# frames len = 543
# frames len = 544
# frames len = 545
# frames len = 546
# frames len = 547
# frames len = 548
# frames len = 549
# frames len = 550
# frames len = 551
# frames len = 552
# frames len = 553
# frames len = 554
# frames len = 555
# frames len = 556
# frames len = 557
# frames len = 558
# frames len = 559
# frames len = 560
# frames len = 561
# frames len = 562
# frames len = 563
# frames len = 564
# frames len = 565
# frames len = 566
# frames len = 567
# frames len = 568
# frames len = 569
# frames len = 570
# frames len = 571
# frames len = 572
# frames len = 573
# frames len = 574
# frames len = 575
# frames len = 576
# frames len = 577
# frames len = 578
# frames len = 579
# frames len = 580
# frames len = 581
# frames len = 582
# frames len = 583
# frames len = 584
# frames len = 585
# frames len = 586
# frames len = 587
# frames len = 588
# frames len = 589
# frames len = 590
# frames len = 591
# frames len = 592
# frames len = 593
# frames len = 594
# frames len = 595
# frames len = 596
# frames len = 597
# frames len = 598
# frames len = 599
# frames len = 600
# frames len = 601
# frames len = 602
# frames len = 603
# frames len = 604
# frames len = 605
# frames len = 606
# frames len = 607
# frames len = 608
# frames len = 609
# frames len = 610
# frames len = 611
# frames len = 612
# frames len = 613
# frames len = 614
# frames len = 615
# frames len = 616
# frames len = 617
# frames len = 618
# frames len = 619
# frames len = 620
# frames len = 621
# frames len = 622
# frames len = 623
# frames len = 624
# frames len = 625
# frames len = 626
# frames len = 627
# frames len = 628
# frames len = 629
# frames len = 630
# frames len = 631
# frames len = 632
# frames len = 633
# frames len = 634
# frames len = 635
# frames len = 636
# frames len = 637
# frames len = 638
# frames len = 639
# frames len = 640
# frames len = 641
# frames len = 642
# frames len = 643
# frames len = 644
# frames len = 645
# frames len = 646
# frames len = 647
# frames len = 648
# frames len = 649
# frames len = 650
# frames len = 651
# frames len = 652
# frames len = 653
# frames len = 654
# frames len = 655
# frames len = 656
# frames len = 657
# frames len = 658
# frames len = 659
# frames len = 660
# frames len = 661
# frames len = 662
# frames len = 663
# frames len = 664
# frames len = 665
# frames len = 666
# frames len = 667
# frames len = 668
# frames len = 669
# frames len = 670
# frames len = 671
# frames len = 672
# frames len = 673
# frames len = 674
# frames len = 675
# frames len = 676
# frames len = 677
# frames len = 678
# frames len = 679
# frames len = 680
# frames len = 681
# frames len = 682
# frames len = 683
# frames len = 684
# frames len = 685
# frames len = 686
# frames len = 687
# frames len = 688
# frames len = 689
# frames len = 690
# frames len = 691
# frames len = 692
# frames len = 693
# frames len = 694
# frames len = 695
# frames len = 696
# frames len = 697
# frames len = 698
# frames len = 699
# frames len = 700
# frames len = 701
# frames len = 702
# frames len = 703
# frames len = 704
# frames len = 705
# frames len = 706
# frames len = 707
# frames len = 708
# frames len = 709
# frames len = 710
# frames len = 711
# frames len = 712
# frames len = 713
# frames len = 714
# frames len = 715
# frames len = 716
# frames len = 717
# frames len = 718
# frames len = 719
# frames len = 720
# frames len = 721
# frames len = 722
# frames len = 723
# frames len = 724
# frames len = 725
# frames len = 726
# frames len = 727
# frames len = 728
# frames len = 729
# frames len = 730
# frames len = 731
# frames len = 732
# frames len = 733
# frames len = 734
# frames len = 735
# frames len = 736
# frames len = 737
# frames len = 738
# frames len = 739
# frames len = 740
# frames len = 741
# frames len = 742
# frames len = 743
# frames len = 744
# frames len = 745
# frames len = 746
# frames len = 747
# frames len = 748
# frames len = 749
# frames len = 750
# frames len = 751
# frames len = 752
# frames len = 753
# frames len = 754
# frames len = 755
# frames len = 756
# frames len = 757
# frames len = 758
# frames len = 759
# frames len = 760
# frames len = 761
# frames len = 762
# frames len = 763
# frames len = 764
# frames len = 765
# frames len = 766
# frames len = 767
# frames len = 768
# frames len = 769
# frames len = 770
# frames len = 771
# frames len = 772
# frames len = 773
# frames len = 774

# %%
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np
from IPython.display import HTML

# re-define the function display_frames_as_gif by Andy 2020-05-17
# to be ran on the Google Colabollation

plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
